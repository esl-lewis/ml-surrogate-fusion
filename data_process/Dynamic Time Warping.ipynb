# %% [markdown]
# # Pulse clustering with Dynamic Time Warping

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

from tslearn import metrics

# %% [markdown]
# Borrows heavily from tslearn. Start by checking DWT implementation on two pulses

# %%
pulse_1 = pd.read_csv("../JET_EFIT_magnetic/99002.csv")
pulse_2 = pd.read_csv("../JET_EFIT_magnetic/99052.csv",)
